# %%
import pandas as pd
import numpy as np

# %%
nd = pd.read_csv("A&A actor ratings.csv")

# %%
nd
# Out:
#                      cast  average rating  total length of movie runtimes  \
# 0              Ellen Page            81.0                             148
# 1      Megumi Hayashibara            81.0                              87
# 2         Koichi Yamadera            81.0                              87
# 3            Akira Ishida            81.0                              87
# 4        Kotono Mitsuishi            81.0                              87
# ...                   ...             ...                             ...
# 1654     Nicholas Pinnock            42.0                             119
# 1655        Johnny Harris            42.0                             119
# 1656       Parker Sawyers            42.0                             119
# 1657       Sofia Boutella            42.0                             119
# 1658          Kyle Soller            42.0                             119
#
#       number of movies stared in
# 0                              1
# ...

# %%
nd=nd[nd['total length of movie runtimes'] >= 140]
g1=nd[nd['number of movies stared in'] == 1]
g1=g1.reset_index()
g1
# Out:
#      index                cast  average rating  \
# 0        0          Ellen Page            81.0
# 1        6        Paolo Stoppa            81.0
# 2        7       Jason Robards            81.0
# 3       10     Charles Bronson            81.0
# 4       11   Claudia Cardinale            81.0
# ..     ...                 ...             ...
# 115   1444        Kevin Spacey            54.0
# 116   1449      Sam Huntington            54.0
# 117   1450        Parker Posey            54.0
# 118   1451       James Marsden            54.0
# 119   1456     Eva Marie Saint            54.0
#
#      total length of movie runtimes  number of movies stared in
# 0                               148                           1
# 1                               166                           1
# 2                               166                           1
# 3                               166                           1
# 4                               166                           1
# ...

# %%
g2=nd[nd['number of movies stared in'] == 2]
g2.reset_index(drop=True,inplace=True )
g2=g2.reset_index()
g2
# Out:
#      index                cast  average rating  \
# 0        0        Ian McKellen            80.5
# 1        1        Bernard Hill            80.5
# 2        2    Dominic Monaghan            80.5
# 3        3     Viggo Mortensen            80.5
# 4        4           Liv Tyler            80.5
# ..     ...                 ...             ...
# 178    178          Eva Mendes            52.5
# 179    179       Rob Schneider            52.0
# 180    180      Philip Arditti            51.5
# 181    181        Tory Kittles            51.0
# 182    182   Luis Da Silva Jr.            44.0
#
#      total length of movie runtimes  number of movies stared in
# 0                               380                           2
# 1                               380                           2
# 2                               380                           2
# 3                               380                           2
# 4                               380                           2
# ...

# %%
g3=nd[nd['number of movies stared in'] == 3]
g3=g3.reset_index()
g3
# Out:
#     index                  cast  average rating  \
# 0      51      John Rhys-Davies       79.000000
# 1     102         Orlando Bloom       76.666667
# 2     137           Elijah Wood       75.666667
# 3     179            Sean Astin       73.695864
# 4     236        Cate Blanchett       72.666667
# 5     333               Xing Yu       71.333333
# 6     370             Lynn Hung       70.666667
# 7     371          Diane Kruger       70.666667
# 8     378    Laurence Fishburne       70.000000
# 9     385      Carrie-Anne Moss       70.000000
# 10    407        Joe Pantoliano       69.000000
# 11    417             Simon Yam       68.333333
# 12    434           Mark Strong       68.000000
# 13    447          Vinnie Jones       67.666667
# 14    458        Sharlto Copley       67.333333
# 15    502      William Fichtner       66.666667
# 16    507        Shah Rukh Khan       66.333333
# 17    571          Tom Sizemore       65.666667
# ...

# %%
g4=nd[nd['number of movies stared in'] == 4]
g4=g4.reset_index()
g4
# Out:
#    index              cast  average rating  total length of movie runtimes  \
# 0    465      Keanu Reeves           67.00                             508
# 1    504         John Hurt           66.50                             503
# 2    570      Bruce Willis           65.75                             452
# 3    729       Don Cheadle           63.75                             456
# 4    829   Monica Bellucci           62.75                             507
# 5    877       John Cleese           62.00                             459
# 6    931        Judi Dench           61.00                             510
# 7   1244          Lucy Liu           58.00                             406
#
#    number of movies stared in
# 0                           4
# 1                           4
# 2                           4
# 3                           4
# 4                           4
# 5                           4
# 6                           4
# 7                           4

# %%
g5=nd[nd['number of movies stared in'] == 5]
g5=g5.reset_index()
g5
# Out:
#    index            cast  average rating  total length of movie runtimes  \
# 0    413      Donnie Yen            68.8                             527
# 1    569   Harrison Ford            65.8                             624
# 2    911     Halle Berry            61.6                             642
# 3   1019  Pierce Brosnan            60.4                             618
# 4   1125     Jackie Chan            59.0                             506
#
#    number of movies stared in
# 0                           5
# 1                           5
# 2                           5
# 3                           5
# 4                           5

# %%
g6=nd[nd['number of movies stared in'] == 6]
g6=g6.reset_index()
g6
# Out:
#    index             cast  average rating  total length of movie runtimes  \
# 0    246     Hugo Weaving       72.333333                             908
# 1    369   Michael Madsen       70.833333                             864
# 2    690        Sean Bean       64.000000                             776
# 3   1276     Nicolas Cage       57.666667                             691
#
#    number of movies stared in
# 0                           6
# 1                           6
# 2                           6
# 3                           6

# %%
nd.corr()
# Out:
#                                 average rating  \
# average rating                        1.000000
# total length of movie runtimes       -0.082813
# number of movies stared in           -0.313328
#
#                                 total length of movie runtimes  \
# average rating                                       -0.082813
# total length of movie runtimes                        1.000000
# number of movies stared in                            0.907129
#
#                                 number of movies stared in
# average rating                                   -0.313328
# total length of movie runtimes                    0.907129
# number of movies stared in                        1.000000

# %%
gv1=71.275000
gv2=64.289869
gv3=64.289869
gv4=63.34375
g5v=63.12
g6v=66.208333
#conclusion:average rating has 0 correlation with number of movies stared in, next path will be to 
#isolate highest rated actors and look for similarities
